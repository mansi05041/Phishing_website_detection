# %% [markdown]
# # DECISION TREE

# %%
# importing variables from pre processing
# %store -r X_train
# %store -r X_test
# %store -r y_train
# %store -r y_test
# %store -r label

# %%
# importing libraries for visualization
import matplotlib.pyplot as plt

# %% [markdown]
# # Training Model

# %%
# importing libraries
from sklearn.tree import DecisionTreeClassifier

# %%
# create a decison tree classifier
DTmodel = DecisionTreeClassifier()

# %%
# Train the model on the training data
DTmodel.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
# Make predictions on the testing data
y_pred = DTmodel.predict(X_test)

# %% [markdown]
# # Model Evaluation

# %%
# import libraries
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import roc_curve, auc

# %%
# Evaluate the model's accuracy
DT_accuracy = accuracy_score(y_test,y_pred)
print("Accuracy:", DT_accuracy)
# Out:
# Accuracy: 0.9615

# %%
# Evaluate the model's precision score
DT_precise = precision_score(y_test,y_pred)
print("Precision Score:", DT_precise)
# Out:
# Precision Score: 0.9567779960707269

# %%
# Evaluate the model's recall score
DT_recall = recall_score(y_test,y_pred)
print("Recall Score:",DT_recall)
# Out:
# Recall Score: 0.9672293942403177

# %%
# Evaluate the model's f1 score
DT_f1Score = f1_score(y_test,y_pred)
print("F1 Score:",DT_f1Score)
# Out:
# F1 Score: 0.9619753086419752

# %%
# confusion matrix
cm = confusion_matrix(y_test,y_pred)

# %%
cm_display = ConfusionMatrixDisplay(confusion_matrix = cm, display_labels=label)
cm_display.plot()
plt.title('Confusion Matrix')
plt.show()

# %% [raw]
# class 1 represents : phishing website
# class 0 represents : legitimate website

# %%
# Evaluate the roc

# compute the ROC curve and AUC for each class
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(len(label)):
    fpr[i], tpr[i], _ = roc_curve(y_test,y_pred)
    roc_auc[i]=auc(fpr[i],tpr[i])

# plot the Roc curve for each class
plt.figure(figsize=(8,6))
for i in range(len(label)):
    plt.plot(fpr[i],tpr[i], label='ROC curve (AUC = %0.2f)' % roc_auc[i])
plt.plot([0,1],[0,1],color='navy',linestyle='--')
plt.xlabel('False Positive rate')
plt.ylabel('True Positive rate')
plt.title('ROC')
plt.legend(loc="lower right")
plt.show()

# %%
# saving the metrics for comparision
# %store DT_accuracy
# %store DT_precise
# %store DT_recall
# %store DT_f1Score
# Out:
# Stored 'DT_accuracy' (float64)
# Stored 'DT_precise' (float64)
# Stored 'DT_recall' (float64)
# Stored 'DT_f1Score' (float64)
